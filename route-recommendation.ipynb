# %% [markdown]
# ### Read File

# %%
import pandas as pd

# %%
data = pd.read_csv('SiafuContext20102015.csv', parse_dates=True, encoding='UTF-8')

# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#                  time       entityID  \
# 0  Text:1445241610000    Text:Blanch
# 1  Text:1445241610000    Text:Wukong
# 2  Text:1445241610000      Text:Blas
# 3  Text:1445241610000  Text:Florence
# 4  Text:1445241610000    Text:Yanyan
#
#                                             position     atDestination  \
# 0  de.nec.nle.siafu.model.Position:-29.7612660670...  BooleanType:true
# 1  de.nec.nle.siafu.model.Position:-29.7614868546...  BooleanType:true
# 2  de.nec.nle.siafu.model.Position:-29.7644050909...  BooleanType:true
# 3  de.nec.nle.siafu.model.Position:-29.7669969456...  BooleanType:true
# 4  de.nec.nle.siafu.model.Position:-29.7617364406...  BooleanType:true
#
#        Activity               Age       Cuisine       Gender  \
# 0   Text:Asleep  IntegerNumber:20  Text:Spanish    Text:Male
# 1  Text:At home  IntegerNumber:44  Text:Italian    Text:Male
# 2  Text:At home  IntegerNumber:27   Text:French    Text:Male
# 3   Text:Asleep  IntegerNumber:17   Text:French  Text:Female
# ...

# %% [markdown]
# ### Preprocess

# %%
cols = list(data)
# data[cols].replace(regex=True,inplace=True,to_replace=r'.*:',value=r'')
data[cols] = data[cols].replace('.*:', '', regex=True)

df = data
df.astype(str)
df['time'] = df['time'].astype(str).astype(int)

# %% [markdown]
# #### Report of Dataset

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(data)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %% [markdown]
# ### Analysis

# %%
import math

# %% [markdown]
# - Date

# %%
def decay_date(value):
    return math.exp(-value/25)

# %% [markdown]
# ### Recommendation
#
# Bibioteca: [SurpriseLib]
#
# [SurpriseLib]: <http://surpriselib.com/>

# %%
from surprise import dump
from surprise import SVD
from surprise import KNNBasic
